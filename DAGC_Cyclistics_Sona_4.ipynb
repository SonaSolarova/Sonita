# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

sns.set_style("darkgrid")

# %%
path = '/Users/SonaSolarova/Documents/STUDIUM/Google_Certificate/8_Capstone_Case Study/case_study_Cyclistic/unpacked_data/08_2021_07_2022'
paths_list = [
    os.path.join(path, f) for f in os.listdir(path)
    if os.path.isfile(os.path.join(path, f))
]

# %%
dataframes = {}
for i, f in enumerate(os.listdir(path)):
    dataframes[f.split('.')[0]] = pd.read_csv(paths_list[i])
dataframes.keys()
# Out:
# dict_keys(['202205-divvy-tripdata', '202109-divvy-tripdata', '202206-divvy-tripdata', '202111-divvy-tripdata', '202112-divvy-tripdata', '202203-divvy-tripdata', '202202-divvy-tripdata', '202201-divvy-tripdata', '202110-divvy-tripdata', '202207-divvy-tripdata', '202204-divvy-tripdata', '202108-divvy-tripdata'])

# %%
df1 = dataframes['202205-divvy-tripdata']
df2 = dataframes['202109-divvy-tripdata']
df3 = dataframes['202206-divvy-tripdata']
df4 = dataframes['202111-divvy-tripdata']
df5 = dataframes['202112-divvy-tripdata']
df6 = dataframes['202203-divvy-tripdata']
df7 = dataframes['202202-divvy-tripdata']
df8 = dataframes['202201-divvy-tripdata']
df9 = dataframes['202110-divvy-tripdata']
df10 = dataframes['202207-divvy-tripdata']
df11 = dataframes['202204-divvy-tripdata']
df12 = dataframes['202108-divvy-tripdata']
union = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12])
print(union)
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       EC2DE40644C6B0F4   classic_bike  2022-05-23 23:06:58
# 1       1C31AD03897EE385   classic_bike  2022-05-11 08:53:28
# 2       1542FBEC830415CF   classic_bike  2022-05-26 18:36:28
# 3       6FF59852924528F8   classic_bike  2022-05-10 07:30:07
# 4       483C52CAAE12E3AC   classic_bike  2022-05-10 17:31:56
# ...                  ...            ...                  ...
# 804347  5E5C9CD681E0419C   classic_bike  2021-08-07 18:07:43
# 804348  96FB57CF4AA456F6  electric_bike  2021-08-09 08:49:31
# 804349  226A0910DCCE904C   classic_bike  2021-08-12 16:55:57
# 804350  1A97D27AE23DE1E7   classic_bike  2021-08-08 22:47:43
# 804351  BBC36E4AA3652361  electric_bike  2021-08-27 18:53:53
#
#                    ended_at                 start_station_name  \
# 0       2022-05-23 23:40:19             Wabash Ave & Grand Ave
# 1       2022-05-11 09:31:22  DuSable Lake Shore Dr & Monroe St
# ...

# %%
union['start_station_name'].nunique()
# Out:
# 1381

# %%
union['end_station_name'].nunique()
# Out:
# 1396

# %%
union['start_station_id'].nunique()
# Out:
# 1226

# %%
union['end_station_id'].nunique()
# Out:
# 1236

# %%
union['ride_id'].nunique()
# Out:
# 5901463

# %%
union['member_casual'].value_counts()
# Out:
# member    3379237
# casual    2522226
# Name: member_casual, dtype: int64

# %%
git init
git add README.md  
git add GeeksForGeeks.ipynb
git commit -m "Cyclistic_Capstone_project" 
git remote add origin https://github.com/{Sonita}/GeeksForGeeks.git 
git push -u origin master
# Out:
#   Input In [28]
#     git init
#         ^
# SyntaxError: invalid syntax

# %%
union.groupby('start_station_id').sum()
# Out:
#                       start_lat      start_lng        end_lat        end_lng
# start_station_id
# 021320              5864.600000  -12275.200000    5866.000309  -12274.513330
# 1011                1718.720000   -3599.390000    1718.900000   -3598.960000
# 1012                 209.010000    -438.050000     209.034982    -438.073124
# 1013                 293.230000    -614.110000     293.254603    -614.056304
# 1016                  41.990000     -87.720000      41.980000     -87.690000
# ...                         ...            ...            ...            ...
# chargingstx0        2306.283185   -4820.899030    2306.010169   -4820.865661
# chargingstx1      215544.266579 -450707.638204  215423.287349 -450431.630513
# chargingstx3      239783.565701 -501788.148789  239789.982280 -501674.348830
# chargingstx4      134745.658662 -281977.495536  134684.049968 -281791.120145
# chargingstx5      145879.029468 -304918.680704  145825.347604 -304807.869721
#
# [1226 rows x 4 columns]

# %%
union = union.create(columns=['start_station_name','start_station_id','end_station_name','end_station_id'])
union = union.drop(columns=['start_lat','start_lng','end_lat','end_lng'])
union.tail()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [301], in <cell line: 1>()
# ----> 1 union1 = union.create(columns=['start_station_name','start_station_id','end_station_name','end_station_id'])
#       2 union1 = union.drop(columns=['start_lat','start_lng','end_lat','end_lng'])
#       3 union1.tail()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'create'

# %%
# Import files 
dataframes = {}
for i, f in enumerate(os.listdir(path)):
    dataframes[f.split('.')[0]] = pd.read_csv(paths_list[i])
dataframes.keys()
# Out:
# dict_keys(['202205-divvy-tripdata', '202109-divvy-tripdata', '202206-divvy-tripdata', '202111-divvy-tripdata', '202112-divvy-tripdata', '202203-divvy-tripdata', '202202-divvy-tripdata', '202201-divvy-tripdata', '202110-divvy-tripdata', '202207-divvy-tripdata', '202204-divvy-tripdata', '202108-divvy-tripdata'])

# %%
# All the tables have the same structure, so I apply union to create one table.
df1 = dataframes['202205-divvy-tripdata']
df2 = dataframes['202109-divvy-tripdata']
df3 = dataframes['202206-divvy-tripdata']
df4 = dataframes['202111-divvy-tripdata']
df5 = dataframes['202112-divvy-tripdata']
df6 = dataframes['202203-divvy-tripdata']
df7 = dataframes['202202-divvy-tripdata']
df8 = dataframes['202201-divvy-tripdata']
df9 = dataframes['202110-divvy-tripdata']
df10 = dataframes['202207-divvy-tripdata']
df11 = dataframes['202204-divvy-tripdata']
df12 = dataframes['202108-divvy-tripdata']
union = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12])
print(union)
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       EC2DE40644C6B0F4   classic_bike  2022-05-23 23:06:58
# 1       1C31AD03897EE385   classic_bike  2022-05-11 08:53:28
# 2       1542FBEC830415CF   classic_bike  2022-05-26 18:36:28
# 3       6FF59852924528F8   classic_bike  2022-05-10 07:30:07
# 4       483C52CAAE12E3AC   classic_bike  2022-05-10 17:31:56
# ...                  ...            ...                  ...
# 804347  5E5C9CD681E0419C   classic_bike  2021-08-07 18:07:43
# 804348  96FB57CF4AA456F6  electric_bike  2021-08-09 08:49:31
# 804349  226A0910DCCE904C   classic_bike  2021-08-12 16:55:57
# 804350  1A97D27AE23DE1E7   classic_bike  2021-08-08 22:47:43
# 804351  BBC36E4AA3652361  electric_bike  2021-08-27 18:53:53
#
#                    ended_at                 start_station_name  \
# 0       2022-05-23 23:40:19             Wabash Ave & Grand Ave
# 1       2022-05-11 09:31:22  DuSable Lake Shore Dr & Monroe St
# ...

# %%
# I delete columns which I won't work in my analysis with.
union = union.drop(columns=['start_lat','start_lng','end_lat','end_lng'])
union.tail()
# Out:
#                  ride_id  rideable_type           started_at  \
# 804347  5E5C9CD681E0419C   classic_bike  2021-08-07 18:07:43
# 804348  96FB57CF4AA456F6  electric_bike  2021-08-09 08:49:31
# 804349  226A0910DCCE904C   classic_bike  2021-08-12 16:55:57
# 804350  1A97D27AE23DE1E7   classic_bike  2021-08-08 22:47:43
# 804351  BBC36E4AA3652361  electric_bike  2021-08-27 18:53:53
#
#                    ended_at        start_station_name start_station_id  \
# 804347  2021-08-07 18:21:21  Wells St & Evergreen Ave     TA1308000049
# 804348  2021-08-09 09:03:51    Broadway & Sheridan Rd            13323
# 804349  2021-08-12 17:15:10    Dearborn St & Adams St     TA1305000005
# 804350  2021-08-08 23:08:12    Broadway & Sheridan Rd            13323
# 804351  2021-08-27 19:02:16   Paulina Ave & North Ave     TA1305000037
#
#                    end_station_name end_station_id member_casual
# 804347  Lincoln Ave & Diversey Pkwy   TA1307000064        member
# ...

# %%
# Check for the datatypes of each column.
union.dtypes
# Out:
# ride_id               object
# rideable_type         object
# started_at            object
# ended_at              object
# start_station_name    object
# start_station_id      object
# end_station_name      object
# end_station_id        object
# member_casual         object
# dtype: object

# %%
# Convert datatypes.
union['started_at'] = union['started_at'].astype('datetime64')
union['ended_at'] = union['ended_at'].astype('datetime64')

# %%
# Find out the duration of each ride. Int32: This Struct is used to represents 32-bit signed integer. The 
#Int32 can store both types of values including negative and positive between the ranges of -2147483648 to +2147483647.
union['ride_duration'] = (union['ended_at'] - union['started_at'])/pd.Timedelta(minutes=1)
union['ride_duration'] = union['ride_duration'].astype('int32')
display(union)
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       EC2DE40644C6B0F4   classic_bike 2022-05-23 23:06:58
# 1       1C31AD03897EE385   classic_bike 2022-05-11 08:53:28
# 2       1542FBEC830415CF   classic_bike 2022-05-26 18:36:28
# 3       6FF59852924528F8   classic_bike 2022-05-10 07:30:07
# 4       483C52CAAE12E3AC   classic_bike 2022-05-10 17:31:56
# ...                  ...            ...                 ...
# 804347  5E5C9CD681E0419C   classic_bike 2021-08-07 18:07:43
# 804348  96FB57CF4AA456F6  electric_bike 2021-08-09 08:49:31
# 804349  226A0910DCCE904C   classic_bike 2021-08-12 16:55:57
# 804350  1A97D27AE23DE1E7   classic_bike 2021-08-08 22:47:43
# 804351  BBC36E4AA3652361  electric_bike 2021-08-27 18:53:53
#
#                   ended_at                 start_station_name  \
# 0      2022-05-23 23:40:19             Wabash Ave & Grand Ave
# 1      2022-05-11 09:31:22  DuSable Lake Shore Dr & Monroe St
# ...

# %%
union.sort_values(by = 'ride_duration')
# Out:
#                  ride_id  rideable_type          started_at  \
# 585672  38B9F148CE80499B  electric_bike 2022-06-07 19:23:03
# 126109  B897BE02B21FA75E  electric_bike 2022-06-07 19:15:39
# 301277  BF114472ABA0289C  electric_bike 2022-06-07 19:14:47
# 126532  072E947E156D142D  electric_bike 2022-06-07 19:14:46
# 576451  BBD84670E05463A9  electric_bike 2022-06-07 19:11:33
# ...                  ...            ...                 ...
# 173598  C8DD5E89BE2DAD7B    docked_bike 2021-11-06 16:53:11
# 610068  94DD1FB2367EA8B6    docked_bike 2022-06-15 07:56:59
# 590027  DCFE0DB8022DFABC    docked_bike 2022-05-08 00:28:53
# 360554  A310C7270FD730B6    docked_bike 2021-10-02 18:35:36
# 192711  E25E58F5E94EE351    docked_bike 2021-08-01 18:53:10
#
#                   ended_at                start_station_name  \
# 585672 2022-06-07 17:05:38                               NaN
# 126109 2022-06-07 17:05:37                               NaN
# ...

# %%
union[union['ride_duration'] < 0].count()
# Out:
# ride_id               96
# rideable_type         96
# started_at            96
# ended_at              96
# start_station_name    74
# start_station_id      74
# end_station_name      72
# end_station_id        72
# member_casual         96
# ride_duration         96
# dtype: int64

# %%
# Drop rows with the negative value
union = pd.DataFrame(union)
union1 = union.loc[union['ride_duration']>=0]

# %%
union1[union1['ride_duration'] < 0].count()
# Out:
# ride_id               0
# rideable_type         0
# started_at            0
# ended_at              0
# start_station_name    0
# start_station_id      0
# end_station_name      0
# end_station_id        0
# member_casual         0
# ride_duration         0
# dtype: int64

# %%
# False starts - the company should find out why this happen. 
# I report this issue in the analysis and delete these rows
union1[union1['ride_duration'] < 1].count()
# Out:
# ride_id               104463
# rideable_type         104463
# started_at            104463
# ended_at              104463
# start_station_name     78488
# start_station_id       78488
# end_station_name       70905
# end_station_id         70905
# member_casual         104463
# ride_duration         104463
# dtype: int64

# %%
union1 = pd.DataFrame(union1)
union2 = union1.loc[union1['ride_duration']>1]
union2[union2['ride_duration'] < 1].count()
# Out:
# ride_id               0
# rideable_type         0
# started_at            0
# ended_at              0
# start_station_name    0
# start_station_id      0
# end_station_name      0
# end_station_id        0
# member_casual         0
# ride_duration         0
# dtype: int64

# %%
n_start_rides = union2.groupby('start_station_id')['ride_id'].count()
print(n_start_rides)
# Out:
# start_station_id
# 021320           128
# 1011              31
# 1012               4
# 1013               7
# 1016               1
#                 ...
# chargingstx0      49
# chargingstx1    4686
# chargingstx3    5214
# chargingstx4    2942
# chargingstx5    3152
# Name: ride_id, Length: 1224, dtype: int64

# %%
member_rides = union2.groupby('member_casual')['ride_id'].count()
print(member_rides)
# Out:
# member_casual
# casual    2456702
# member    3245180
# Name: ride_id, dtype: int64

# %%
# Convert datatypes for each column.
union2 = union2.astype({'ride_id':'string','start_station_name':'string','start_station_id':'string','end_station_name':'string','end_station_id':'string','rideable_type':'category', 'member_casual':'category'})
union2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5701882 entries, 0 to 804351
# Data columns (total 10 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             string
#  1   rideable_type       category
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  string
#  5   start_station_id    string
#  6   end_station_name    string
#  7   end_station_id      string
#  8   member_casual       category
#  9   ride_duration       int32
# dtypes: category(2), datetime64[ns](2), int32(1), string(5)
# memory usage: 380.6 MB

# %%
# Print null values
union2.isna().sum()
# Out:
# ride_id                    0
# rideable_type              0
# started_at                 0
# ended_at                   0
# start_station_name    812554
# start_station_id      812552
# end_station_name      862401
# end_station_id        862401
# member_casual              0
# ride_duration              0
# dtype: int64

# %%
union2.shape
# Out:
# (5701882, 10)

# %%
# Drop all rows with any NaN and NaT values
union3 = union2.dropna()
union3.isna().sum()
# Out:
# ride_id               0
# rideable_type         0
# started_at            0
# ended_at              0
# start_station_name    0
# start_station_id      0
# end_station_name      0
# end_station_id        0
# member_casual         0
# ride_duration         0
# dtype: int64

# %%
# Number of rows and columns
union3.shape
# Out:
# (4494737, 10)

# %%
# Strip Leading and Trailing Space of the column ride_id
union3['ride_id'] = union3['ride_id'].str.strip()
print (union3)
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       EC2DE40644C6B0F4   classic_bike 2022-05-23 23:06:58
# 1       1C31AD03897EE385   classic_bike 2022-05-11 08:53:28
# 2       1542FBEC830415CF   classic_bike 2022-05-26 18:36:28
# 3       6FF59852924528F8   classic_bike 2022-05-10 07:30:07
# 4       483C52CAAE12E3AC   classic_bike 2022-05-10 17:31:56
# ...                  ...            ...                 ...
# 804347  5E5C9CD681E0419C   classic_bike 2021-08-07 18:07:43
# 804348  96FB57CF4AA456F6  electric_bike 2021-08-09 08:49:31
# 804349  226A0910DCCE904C   classic_bike 2021-08-12 16:55:57
# 804350  1A97D27AE23DE1E7   classic_bike 2021-08-08 22:47:43
# 804351  BBC36E4AA3652361  electric_bike 2021-08-27 18:53:53
#
#                   ended_at                 start_station_name  \
# 0      2022-05-23 23:40:19             Wabash Ave & Grand Ave
# 1      2022-05-11 09:31:22  DuSable Lake Shore Dr & Monroe St
# ...

# %%
# Strip Leading and Trailing Space of the column start_station_id
union3['start_station_id'] = union3['start_station_id'].str.strip()
print (union3)
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       EC2DE40644C6B0F4   classic_bike 2022-05-23 23:06:58
# 1       1C31AD03897EE385   classic_bike 2022-05-11 08:53:28
# 2       1542FBEC830415CF   classic_bike 2022-05-26 18:36:28
# 3       6FF59852924528F8   classic_bike 2022-05-10 07:30:07
# 4       483C52CAAE12E3AC   classic_bike 2022-05-10 17:31:56
# ...                  ...            ...                 ...
# 804347  5E5C9CD681E0419C   classic_bike 2021-08-07 18:07:43
# 804348  96FB57CF4AA456F6  electric_bike 2021-08-09 08:49:31
# 804349  226A0910DCCE904C   classic_bike 2021-08-12 16:55:57
# 804350  1A97D27AE23DE1E7   classic_bike 2021-08-08 22:47:43
# 804351  BBC36E4AA3652361  electric_bike 2021-08-27 18:53:53
#
#                   ended_at                 start_station_name  \
# 0      2022-05-23 23:40:19             Wabash Ave & Grand Ave
# 1      2022-05-11 09:31:22  DuSable Lake Shore Dr & Monroe St
# ...

# %%
# Strip Leading and Trailing Space of the column end_station_id
union3['end_station_id'] = union3['end_station_id'].str.strip()
print (union3)
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       EC2DE40644C6B0F4   classic_bike 2022-05-23 23:06:58
# 1       1C31AD03897EE385   classic_bike 2022-05-11 08:53:28
# 2       1542FBEC830415CF   classic_bike 2022-05-26 18:36:28
# 3       6FF59852924528F8   classic_bike 2022-05-10 07:30:07
# 4       483C52CAAE12E3AC   classic_bike 2022-05-10 17:31:56
# ...                  ...            ...                 ...
# 804347  5E5C9CD681E0419C   classic_bike 2021-08-07 18:07:43
# 804348  96FB57CF4AA456F6  electric_bike 2021-08-09 08:49:31
# 804349  226A0910DCCE904C   classic_bike 2021-08-12 16:55:57
# 804350  1A97D27AE23DE1E7   classic_bike 2021-08-08 22:47:43
# 804351  BBC36E4AA3652361  electric_bike 2021-08-27 18:53:53
#
#                   ended_at                 start_station_name  \
# 0      2022-05-23 23:40:19             Wabash Ave & Grand Ave
# 1      2022-05-11 09:31:22  DuSable Lake Shore Dr & Monroe St
# ...

# %%
# Remove duplicates according primary key
union3[union3['ride_id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, member_casual, ride_duration, journey]
# Index: []

# %%
union3.groupby("start_station_name", sort=False)["ride_id"].count()
# Out:
# start_station_name
# Wabash Ave & Grand Ave                  28582
# DuSable Lake Shore Dr & Monroe St       40277
# Clinton St & Madison St                 25092
# Carpenter St & Huron St                 11021
# Noble St & Milwaukee Ave                 8944
#                                         ...
# Sangamon St & 79th St                       1
# Western Ave & 111th St - SW                 1
# Public Rack - Al Raby School                1
# Public Rack - Stony Island & 87th St        1
# 351                                         1
# Name: ride_id, Length: 1295, dtype: int64

# %%
# Top used start_station_id by ride_id count
union3.groupby("start_station_id", sort=False)["ride_id"].count()
# Out:
# start_station_id
# TA1307000117    28582
# 13300           40277
# TA1305000032    25092
# 13196           11021
# 13290            8944
#                 ...
# 934                 1
# 887                 1
# 679                 1
# 940                 1
# DIVVY 001           1
# Name: ride_id, Length: 1161, dtype: int64

# %%
n_start_rides = union3.groupby(['start_station_id']).count()
n_start_rides.head()
# Out:
#                   ride_id  rideable_type  started_at  ended_at  \
# start_station_id
# 021320                 76             76          76        76
# 1011                    8              8           8         8
# 1012                    2              2           2         2
# 1013                    2              2           2         2
# 1019                    5              5           5         5
#
#                   start_station_name  end_station_name  end_station_id  \
# start_station_id
# 021320                            76                76              76
# 1011                               8                 8               8
# 1012                               2                 2               2
# 1013                               2                 2               2
# 1019                               5                 5               5
#
#                   member_casual  ride_duration  journey  year  month  \
# start_station_id
# ...

# %%
rn_start_rides = union3.groupby('start_station_name')['ride_id'].count().reset_index(name='count_ride_id')
rn_start_rides.head()
# Out:
#                   start_station_name  count_ride_id
# 0       111th St - Morgan Park Metra              3
# 1                2112 W Peterson Ave            784
# 2                                351              1
# 3                      532 E 43rd St             14
# 4  63rd & Western Ave - north corner              1

# %%
# Top 5 start_station by count of ride_id
rn_start_rides.sort_values(by='count_ride_id', ascending=False)
# Out:
#                       start_station_name  count_ride_id
# 1152             Streeter Dr & Grand Ave          74989
# 331   DuSable Lake Shore Dr & North Blvd          42366
# 330    DuSable Lake Shore Dr & Monroe St          40277
# 728                Michigan Ave & Oak St          40205
# 1217               Wells St & Concord Ln          38915
# ...                                  ...            ...
# 583         Lafayette Ave & 87th St - SW              1
# 585                  Laflin St & 51st St              1
# 588              Lake Park Ave & 44th St              1
# 1203                 Wallace St & 112 St              1
# 435                 Halsted St & 80th St              1
#
# [1295 rows x 2 columns]

# %%
rn_end_rides = union3.groupby('end_station_name')['ride_id'].count().reset_index(name='count_ride_id')
rn_end_rides.head()
# Out:
#                     end_station_name  count_ride_id
# 0           10101 S Stony Island Ave              2
# 1       111th St - Morgan Park Metra              1
# 2                2112 W Peterson Ave            967
# 3                      532 E 43rd St             13
# 4  63rd & Western Ave - north corner              4

# %%
# Top 5 end_station by count of ride_id
rn_end_rides.sort_values(by='count_ride_id', ascending=False)
# Out:
#                              end_station_name  count_ride_id
# 1165                  Streeter Dr & Grand Ave          76367
# 340        DuSable Lake Shore Dr & North Blvd          46811
# 741                     Michigan Ave & Oak St          41029
# 339         DuSable Lake Shore Dr & Monroe St          39252
# 1231                    Wells St & Concord Ln          39032
# ...                                       ...            ...
# 661                  Linder Ave & Belmont Ave              1
# 1070                    Sawyer Ave & 111th St              1
# 695                   Marquette Ave & 83rd St              1
# 933   Public Rack - Laramie Ave & Warwick Ave              1
# 1313                           Zapata Academy              1
#
# [1314 rows x 2 columns]

# %%
#Testing groupby function
# Average ride_duration by users
union3.groupby('member_casual',sort=True)['ride_duration'].mean()
# Out:
# member_casual
# casual    26.677002
# member    12.532500
# Name: ride_duration, dtype: float64

# %%
# Combine to columns start_station_name & end_station_name to create new column "journey"
union3["journey"] = union3['start_station_name'].astype(str) +"-"+ union3["end_station_name"]
print(union3)
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       EC2DE40644C6B0F4   classic_bike 2022-05-23 23:06:58
# 1       1C31AD03897EE385   classic_bike 2022-05-11 08:53:28
# 2       1542FBEC830415CF   classic_bike 2022-05-26 18:36:28
# 3       6FF59852924528F8   classic_bike 2022-05-10 07:30:07
# 4       483C52CAAE12E3AC   classic_bike 2022-05-10 17:31:56
# ...                  ...            ...                 ...
# 804347  5E5C9CD681E0419C   classic_bike 2021-08-07 18:07:43
# 804348  96FB57CF4AA456F6  electric_bike 2021-08-09 08:49:31
# 804349  226A0910DCCE904C   classic_bike 2021-08-12 16:55:57
# 804350  1A97D27AE23DE1E7   classic_bike 2021-08-08 22:47:43
# 804351  BBC36E4AA3652361  electric_bike 2021-08-27 18:53:53
#
#                   ended_at                 start_station_name  \
# 0      2022-05-23 23:40:19             Wabash Ave & Grand Ave
# 1      2022-05-11 09:31:22  DuSable Lake Shore Dr & Monroe St
# ...

# %%
# Combine to columns start_station_id & end_station_id to create new column "SE_station"
union3["SE_station"] = union3['start_station_id'].astype(str) +"-"+ union3["end_station_id"]
union3.head()
# Out:
#             ride_id rideable_type          started_at            ended_at  \
# 0  EC2DE40644C6B0F4  classic_bike 2022-05-23 23:06:58 2022-05-23 23:40:19
# 1  1C31AD03897EE385  classic_bike 2022-05-11 08:53:28 2022-05-11 09:31:22
# 2  1542FBEC830415CF  classic_bike 2022-05-26 18:36:28 2022-05-26 18:58:18
# 3  6FF59852924528F8  classic_bike 2022-05-10 07:30:07 2022-05-10 07:38:49
# 4  483C52CAAE12E3AC  classic_bike 2022-05-10 17:31:56 2022-05-10 17:36:57
#
#                   start_station_name start_station_id  \
# 0             Wabash Ave & Grand Ave     TA1307000117
# 1  DuSable Lake Shore Dr & Monroe St            13300
# 2            Clinton St & Madison St     TA1305000032
# 3            Clinton St & Madison St     TA1305000032
# 4            Clinton St & Madison St     TA1305000032
#
#               end_station_name end_station_id member_casual  ride_duration  \
# 0       Halsted St & Roscoe St   TA1309000025        member             33
# ...

# %%
# Combine to columns end_station_id & start_station_id to create new column "ES_station"
union3["ES_station"] = union3['end_station_id'].astype(str) +"-"+ union3["start_station_id"].astype(str)
union3.head()
# Out:
#             ride_id rideable_type          started_at            ended_at  \
# 0  EC2DE40644C6B0F4  classic_bike 2022-05-23 23:06:58 2022-05-23 23:40:19
# 1  1C31AD03897EE385  classic_bike 2022-05-11 08:53:28 2022-05-11 09:31:22
# 2  1542FBEC830415CF  classic_bike 2022-05-26 18:36:28 2022-05-26 18:58:18
# 3  6FF59852924528F8  classic_bike 2022-05-10 07:30:07 2022-05-10 07:38:49
# 4  483C52CAAE12E3AC  classic_bike 2022-05-10 17:31:56 2022-05-10 17:36:57
#
#                   start_station_name start_station_id  \
# 0             Wabash Ave & Grand Ave     TA1307000117
# 1  DuSable Lake Shore Dr & Monroe St            13300
# 2            Clinton St & Madison St     TA1305000032
# 3            Clinton St & Madison St     TA1305000032
# 4            Clinton St & Madison St     TA1305000032
#
#               end_station_name end_station_id member_casual  ride_duration  \
# 0       Halsted St & Roscoe St   TA1309000025        member             33
# ...

# %%
# Combine to columns SE_station & ES_station to create new column "journey_id"
union3["journey_id"] = union3['SE_station'].astype(str) +"-"+ union3["ES_station"]
union3.head()
# Out:
#             ride_id rideable_type          started_at            ended_at  \
# 0  EC2DE40644C6B0F4  classic_bike 2022-05-23 23:06:58 2022-05-23 23:40:19
# 1  1C31AD03897EE385  classic_bike 2022-05-11 08:53:28 2022-05-11 09:31:22
# 2  1542FBEC830415CF  classic_bike 2022-05-26 18:36:28 2022-05-26 18:58:18
# 3  6FF59852924528F8  classic_bike 2022-05-10 07:30:07 2022-05-10 07:38:49
# 4  483C52CAAE12E3AC  classic_bike 2022-05-10 17:31:56 2022-05-10 17:36:57
#
#                   start_station_name start_station_id  \
# 0             Wabash Ave & Grand Ave     TA1307000117
# 1  DuSable Lake Shore Dr & Monroe St            13300
# 2            Clinton St & Madison St     TA1305000032
# 3            Clinton St & Madison St     TA1305000032
# 4            Clinton St & Madison St     TA1305000032
#
#               end_station_name end_station_id member_casual  ride_duration  \
# 0       Halsted St & Roscoe St   TA1309000025        member             33
# ...

# %%
# Find repeated journeys in particular dates
rn_end_rides = union3.groupby('started_at')['SE_station'].count().reset_index(name='count_SE_station')
rn_end_rides.head()
# Out:
#            started_at  count_SE_station
# 0 2021-08-01 00:00:04                 1
# 1 2021-08-01 00:00:17                 1
# 2 2021-08-01 00:00:19                 1
# 3 2021-08-01 00:00:27                 1
# 4 2021-08-01 00:00:32                 1

# %%
# Combine 4 columns start_station_id & end_station_id & end_station_id & start_station_id to create new column "journey_id"
union3["journey_id"] = union3['start_station_id'].astype(str) +"-"+ union3['end_station_id'].astype(str)+"-"+ union3['end_station_id'].astype(str)+"-"+ union3['start_station_id'].astype(str)
print(union3[['ride_id','start_station_id', 'end_station_id','journey_id']])
# Out:
#                  ride_id start_station_id end_station_id  \
# 0       EC2DE40644C6B0F4     TA1307000117   TA1309000025
# 1       1C31AD03897EE385            13300          15534
# 2       1542FBEC830415CF     TA1305000032          13221
# 3       6FF59852924528F8     TA1305000032   TA1305000030
# 4       483C52CAAE12E3AC     TA1305000032   TA1306000015
# ...                  ...              ...            ...
# 804347  5E5C9CD681E0419C     TA1308000049   TA1307000064
# 804348  96FB57CF4AA456F6            13323          13179
# 804349  226A0910DCCE904C     TA1305000005          13179
# 804350  1A97D27AE23DE1E7            13323   TA1309000035
# 804351  BBC36E4AA3652361     TA1305000037          13058
#
#                                                journey_id
# 0       TA1307000117-TA1309000025-TA1309000025-TA13070...
# 1                                 13300-15534-15534-13300
# 2                   TA1305000032-13221-13221-TA1305000032
# ...

# %%
top_journey = union3.groupby("journey_id")["ride_id"].count().reset_index(name='count_ride_id')
top_journey.head()
# Out:
#                   journey_id  count_ride_id
# 0  021320-13001-13001-021320              1
# 1  021320-13063-13063-021320              1
# 2  021320-13073-13073-021320              1
# 3  021320-13089-13089-021320              1
# 4  021320-13138-13138-021320              1

# %%
# Top 5 journey_id by count of ride_id
top_journey.sort_values(by='count_ride_id', ascending=False)
# Out:
#                                               journey_id  count_ride_id
# 3004                             13022-13022-13022-13022          10626
# 87573  KA1503000014-KA1504000076-KA1504000076-KA15030...           6726
# 87569  KA1503000014-KA1503000071-KA1503000071-KA15030...           6492
# 38025                            13300-13300-13300-13300           6448
# 93129  KA1503000071-KA1503000014-KA1503000014-KA15030...           6194
# ...                                                  ...            ...
# 84235                  752-TA1309000002-TA1309000002-752              1
# 84236                                753-13042-13042-753              1
# 84238                  753-KA1503000023-KA1503000023-753              1
# 84239                  753-KA1503000059-KA1503000059-753              1
# 82567                                654-13277-13277-654              1
#
# [165135 rows x 2 columns]

# %%
import numpy as np
import pandas as pd
from pandas.api.types import CategoricalDtype

# %%
union3['year'] = union3['started_at'].dt.year

cats1 = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
union3['month'] = union3['started_at'].dt.month_name()
union3['month'] = union3['month'].astype(CategoricalDtype(categories=cats1, ordered=False))

cats2 = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
union3['day_of_week'] = union3['started_at'].dt.day_name()
union3['day_of_week'] = union3['day_of_week'].astype(CategoricalDtype(categories=cats2, ordered=False))

union3['hour'] = union3['started_at'].dt.hour
union3 = union3.astype({'year':'int16', 'hour':'int8'})

union3.head()
# Out:
#             ride_id rideable_type          started_at            ended_at  \
# 0  EC2DE40644C6B0F4  classic_bike 2022-05-23 23:06:58 2022-05-23 23:40:19
# 1  1C31AD03897EE385  classic_bike 2022-05-11 08:53:28 2022-05-11 09:31:22
# 2  1542FBEC830415CF  classic_bike 2022-05-26 18:36:28 2022-05-26 18:58:18
# 3  6FF59852924528F8  classic_bike 2022-05-10 07:30:07 2022-05-10 07:38:49
# 4  483C52CAAE12E3AC  classic_bike 2022-05-10 17:31:56 2022-05-10 17:36:57
#
#                   start_station_name start_station_id  \
# 0             Wabash Ave & Grand Ave     TA1307000117
# 1  DuSable Lake Shore Dr & Monroe St            13300
# 2            Clinton St & Madison St     TA1305000032
# 3            Clinton St & Madison St     TA1305000032
# 4            Clinton St & Madison St     TA1305000032
#
#               end_station_name end_station_id member_casual  ride_duration  \
# 0       Halsted St & Roscoe St   TA1309000025        member             33
# ...

# %%
# Why would casual riders buy Cyclistic annual memberships?
# We find out if "casual" users use the service regularly for commuting to work. 
# Especially for them the company prepares marketing campaign.
# We selected most repeated journes as a combination of start and end station in both directions
# We create pivot table to see the user behaviour.

# %%
import plotly.express as px

# %%
member_rides = union3.groupby('member_casual')['ride_id'].count()
print(member_rides)
# Out:
# member_casual
# casual    1908902
# member    2585835
# Name: ride_id, dtype: int64

# %%
objects = ('casual = 1 908 902', 'member = 2 585 835')
y_pos = np.arange(len(objects))
performance = [1908902,2585835]

plt.barh(y_pos, performance, align='center', alpha=0.5, color=['yellow', 'lightgreen'])
plt.yticks(y_pos, objects)
plt.xlabel('ride_id_count')
plt.title('Number of rides by casual/member')


plt.show()

# %%
# library
import matplotlib.pyplot as plt

# create data
names = ['casual=1 908 902 rides', 'member=2 585 835']
rides = [1908902,2585835]
 
# Create a circle at the center of the plot
my_circle = plt.Circle( (0,0), 0.7, color='white')

# Custom wedges
plt.pie(rides, labels=names, wedgeprops = { 'linewidth' : 7, 'edgecolor' : 'white' })
p = plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %%
# Number of Rides / month
union3_pv1 = pd.pivot_table(union3,
              index = ['year', 'month', 'member_casual'],
              values = ['ride_id','ride_duration'],
              aggfunc = {'ride_id':'count','ride_duration':[min, max,'np.mean']})
union3_pv1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [276], in <cell line: 2>()
#       1 # Number of Rides / month
# ----> 2 union3_pv1 = pd.pivot_table(union3,
#       3               index = ['year', 'month', 'member_casual'],
#       4               values = ['ride_id','ride_duration'],
#       5               aggfunc = {'ride_id':'count','ride_duration':[min, max,'np.mean']})
#       6 union3_pv1
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/pivot.py:95, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      92     table = concat(pieces, keys=keys, axis=1)
#      93     return table.__finalize__(data, method="pivot_table")
# ---> 95 table = __internal_pivot_table(
#      96     data,
#      97     values,
#      98     index,
#      99     columns,
#     100     aggfunc,
# ...

# %%
# Number of Rides / month
union3_pv1 = pd.pivot_table(union3,
              index = ['year', 'month', 'member_casual'],
              values = 'ride_id',
              aggfunc = ['count'],
              margins = True,
              margins_name = 'Total Count')
union3_pv1 = union3_pv1.loc[(union3_pv1 != 0).any(axis=1)]
union3_pv1
# Out:
#                                        count
#                                      ride_id
# year        month     member_casual
# 2021        August    casual          335800
#                       member          322997
#             September casual          288063
#                       member          318469
#             October   casual          185939
#                       member          278967
#             November  casual           68699
#                       member          178973
#             December  casual           44336
#                       member          126287
# 2022        January   casual           12372
#                       member           65051
#             February  casual           14844
#                       member           71027
#             March     casual           65919
#                       member          143309
#             April     casual           90110
#                       member          173452
# ...

# %%
import plotly.express as px
fig_2 = union3.groupby(['year', 'month', 'member_casual'], as_index=False).count()
fig_2 = fig_2[fig_2['ride_id'] != 0]

px.line(fig_2, x = 'month', y = 'ride_id', range_y = [0,450000],
        color = 'member_casual', 
        line_shape = 'spline',
        markers=True, 
        labels = {'ride_id': 'No. of Rides', 'month': 'Months (Oct 2020 - Sep 2021)', 'member_casual': 'Member/Casual'},
        hover_name = 'member_casual', hover_data = {'member_casual': False, 'month': True, 'ride_id': True}, 
        color_discrete_map = {'casual': '#FF934F', 'member': '#058ED9'})
fig_2.show()

# %%
# The business task: How do annual members and casual riders use Cyclistic bikes differently?
# We have a look at users behaviour during the year, months, weekdays

# %%
# Avg ride duration (06/2021-07/2022) by users
pd.pivot_table(union3,
               index = 'member_casual',
               values = ['ride_duration'],
               aggfunc = ['mean'],
               margins = True,
               margins_name = 'Total Ride Average Duration')
# Out:
#                                      mean
#                             ride_duration
# member_casual
# casual                          26.677002
# member                          12.532500
# Total Ride Average Duration     18.539630

# %%
import matplotlib.pyplot as plt

Tasks = [26.677002,12.532500]

my_labels = 'casual','member'
my_colors = ['yellow','lightgreen']
my_explode = (0, 0.1)
plt.pie(Tasks, labels=my_labels, autopct='%0.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.title('Average ride duration (06/2021-07/2022)')
plt.axis('equal')
plt.legend()
plt.show()

# %%
# Average Ride Duration by users / month
pd.pivot_table(union3,
               index = ['year', 'month','member_casual'],
               values = ['ride_duration'],
               aggfunc = ['mean'],
               margins = True,
               margins_name = 'Total Ride Average Duration')
# Out:
#                                                              mean
#                                                     ride_duration
# year                        month     member_casual
# 2021                        August    casual            28.541078
#                                       member            13.449363
#                             September casual            28.056922
#                                       member            13.012039
#                             October   casual            26.257283
#                                       member            11.915087
#                             November  casual            22.388652
#                                       member            10.844463
#                             December  casual            24.753541
#                                       member            10.467982
# 2022                        January   casual            27.361785
# ...

# %%
# Average Ride Duration by users / weekday
pd.pivot_table(union3,
               index = ['day_of_week', 'member_casual'],
               values = ['ride_duration'],
               aggfunc = ['mean'],
               margins = True,
               margins_name = 'Total Ride Average Duration')
# Out:
#                                                    mean
#                                           ride_duration
# day_of_week                 member_casual
# Sunday                      casual            30.770022
#                             member            14.341603
# Monday                      casual            27.752140
#                             member            12.136216
# Tuesday                     casual            23.182261
#                             member            11.652197
# Wednesday                   casual            22.779415
#                             member            11.790643
# Thursday                    casual            23.392058
#                             member            11.973800
# Friday                      casual            24.668303
#                             member            12.178661
# Saturday                    casual            29.142569
#                             member            14.209842
# ...

# %%
fig_3 = union3.groupby(['day_of_week', 'member_casual'], as_index=False).count()

px.line(fig_3, x = 'day_of_week', y = 'ride_id', range_y = [0,550000],
        color = 'member_casual',  
        line_shape = 'spline',
        markers=True,
        labels = {'ride_id': 'No. of Rides', 'day_of_week': 'Weekdays', 'member_casual': 'Member/Casual'},
        hover_name = 'member_casual', hover_data = {'member_casual': False, 'month': False, 'ride_id': True}, 
        color_discrete_map = {'casual': '#FF934F', 'member': '#058ED9'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [278], in <cell line: 3>()
#       1 fig_3 = union3.groupby(['day_of_week', 'member_casual'], as_index=False).count()
# ----> 3 px.line(fig_3, x = 'day_of_week', y = 'ride_id', range_y = [0,550000],
#       4         color = 'member_casual',
#       5         line_shape = 'spline',
#       6         markers=True,
#       7         labels = {'ride_id': 'No. of Rides', 'day_of_week': 'Weekdays', 'member_casual': 'Member/Casual'},
#       8         hover_name = 'member_casual', hover_data = {'member_casual': False, 'month': False, 'ride_id': True},
#       9         color_discrete_map = {'casual': '#FF934F', 'member': '#058ED9'})
#
# NameError: name 'px' is not defined

# %%
# Count of rideable type by users
pd.pivot_table(union3,
               index = ['rideable_type', 'member_casual'],
               values = ['ride_id'],
               aggfunc = ['count'],
               margins = True,
               margins_name = 'Total Rides')
# Out:
#                                count
#                              ride_id
# rideable_type member_casual
# classic_bike  casual         1106081
#               member         1858167
# docked_bike   casual          222525
#               member               0
# electric_bike casual          580296
#               member          727668
# Total Rides                  4494737

# %%
# Average Number of Rides in Each Hour
pd.pivot_table(union3,
              index = ['hour', 'member_casual'],
              values = 'ride_id',
              aggfunc = ['count'],
              margins = True,
              margins_name = 'Total Count')
# Out:
#                              count
#                            ride_id
# hour        member_casual
# 0           casual           36844
#             member           25209
# 1           casual           24995
#             member           15649
# 2           casual           15499
#             member            8594
# 3           casual            8487
#             member            5136
# 4           casual            5701
#             member            6071
# 5           casual            8896
#             member           26957
# 6           casual           20410
#             member           74199
# 7           casual           38268
#             member          140481
# 8           casual           52097
#             member          164344
# 9           casual           59218
#             member          112153
# 10          casual           80564
#             member          104879
# 11          casual          106099
#             member          126592
# ...

# %%
fig_4 = union3.groupby(['hour', 'member_casual'], as_index=False).count()

fig_4a = px.line(fig_4, x = 'hour', y = 'ride_id', range_x = [0,23], range_y = [0,300000],
                 color = 'member_casual',
                 line_shape = 'spline',
                 markers=True,
                 labels = {'ride_id': 'No. of Rides', 'hour': '24 Hours', 'member_casual': 'Member/Casual'},
                 hover_name = 'member_casual', hover_data = {'member_casual': False, 'month': False, 'ride_id': True},
                 color_discrete_map = {'casual': '#FF934F', 'member': '#058ED9'})
fig_4a.update_xaxes(dtick=1)
fig_4a.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [281], in <cell line: 3>()
#       1 fig_4 = union3.groupby(['hour', 'member_casual'], as_index=False).count()
# ----> 3 fig_4a = px.line(fig_4, x = 'hour', y = 'ride_id', range_x = [0,23], range_y = [0,300000],
#       4                  color = 'member_casual',
#       5                  line_shape = 'spline',
#       6                  markers=True,
#       7                  labels = {'ride_id': 'No. of Rides', 'hour': '24 Hours', 'member_casual': 'Member/Casual'},
#       8                  hover_name = 'member_casual', hover_data = {'member_casual': False, 'month': False, 'ride_id': True},
#       9                  color_discrete_map = {'casual': '#FF934F', 'member': '#058ED9'})
#      10 fig_4a.update_xaxes(dtick=1)
#      11 fig_4a.show()
#
# NameError: name 'px' is not defined

# %%
# Analyzing Difference in Average Ride Length Between Casual riders and Members.
# Average Ride Length in 1 Year
pd.pivot_table(union3,
               index = 'member_casual',
               values = ['ride_duration'],
               aggfunc = ['mean'],
               margins = True,
               margins_name = 'Total Ride Average')
# Out:
#                             mean
#                    ride_duration
# member_casual
# casual                 26.677002
# member                 12.532500
# Total Ride Average     18.539630

# %%
fig_4 = round(union3.groupby('member_casual', as_index=False).mean(),2)

px.bar(fig_4, y = 'member_casual', x = 'ride_length', range_x = [0,35],
        color = 'member_casual', 
        height = 300,
        text = 'ride_duration', 
        labels = {'ride_duration': 'Average Ride Duration (minutes)', 'member_casual': 'Member/Casual'},
        hover_name = 'member_casual', hover_data = {'member_casual': False, 'ride_duration': True}, 
        color_discrete_map = {'casual': '#FF934F', 'member': '#058ED9'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [284], in <cell line: 3>()
#       1 fig_4 = round(union3.groupby('member_casual', as_index=False).mean(),2)
# ----> 3 px.bar(fig_4, y = 'member_casual', x = 'ride_length', range_x = [0,35],
#       4         color = 'member_casual',
#       5         height = 300,
#       6         text = 'ride_duration',
#       7         labels = {'ride_duration': 'Average Ride Duration (minutes)', 'member_casual': 'Member/Casual'},
#       8         hover_name = 'member_casual', hover_data = {'member_casual': False, 'ride_duration': True},
#       9         color_discrete_map = {'casual': '#FF934F', 'member': '#058ED9'})
#
# NameError: name 'px' is not defined

# %%
# Average Ride Length in each WeekDay
pd.pivot_table(union3,
               index = ['day_of_week', 'member_casual'],
               values = ['ride_duration'],
               aggfunc = ['mean'],
               margins = True,
               margins_name = 'Total Ride Average')
# Out:
#                                           mean
#                                  ride_duration
# day_of_week        member_casual
# Sunday             casual            30.770022
#                    member            14.341603
# Monday             casual            27.752140
#                    member            12.136216
# Tuesday            casual            23.182261
#                    member            11.652197
# Wednesday          casual            22.779415
#                    member            11.790643
# Thursday           casual            23.392058
#                    member            11.973800
# Friday             casual            24.668303
#                    member            12.178661
# Saturday           casual            29.142569
#                    member            14.209842
# Total Ride Average                   18.539630

# %%
# Average Ride Length in each WeekDay
pd.pivot_table(union3,
               index = ['day_of_week', 'member_casual'],
               values = ['ride_duration'],
               aggfunc = ['mean'],
               margins = True,
               margins_name = 'Total Ride Average')
# Out:
#                                           mean
#                                  ride_duration
# day_of_week        member_casual
# Sunday             casual            30.770022
#                    member            14.341603
# Monday             casual            27.752140
#                    member            12.136216
# Tuesday            casual            23.182261
#                    member            11.652197
# Wednesday          casual            22.779415
#                    member            11.790643
# Thursday           casual            23.392058
#                    member            11.973800
# Friday             casual            24.668303
#                    member            12.178661
# Saturday           casual            29.142569
#                    member            14.209842
# Total Ride Average                   18.539630
